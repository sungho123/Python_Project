# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import math
import datetime
from pandas import Series, DataFrame

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "./input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
# Out:
# angpyeongdong_noin_(1)_2011.csv
# angpyeongdong_noin_(1)_2012.csv
# angpyeongdong_noin_(1)_2013.csv
# angpyeongdong_noin_(1)_2014.csv
# daelimdong_yusuji(3)_2013.csv
# daelimdong_yusuji(3)_2014.csv
# dangsan_middle_school(2)_2013.csv
# dangsan_middle_school(2)_2014.csv
# dong-a-ecobil_apt(1)_2011.csv
# dong-a-ecobil_apt(1)_2012.csv
# dong-a-ecobil_apt(1)_2013.csv
# dong-a-ecobil_apt(1)_2014.csv
# duam_children_park(1)_2013.csv
# duam_children_park(1)_2014.csv
# info.csv
# kbs(2)_2012.csv
# kbs(2)_2013.csv
# kbs(2)_2014.csv
# kim_hospital(1)_2013.csv
# kim_hospital(1)_2014.csv
# munlaedong_bismul_peompeujang(3)_2014.csv
# munlaedong_bismul_peompeujang(3)_2015.csv
# munlae_green_park(1)_2013.csv
# munlae_green_park(1)_2014.csv
# national_assembly_hall(2)_2012.csv
# national_assembly_hall(2)_2014.csv
# predict_data.csv
# sal_lesi_o(1)_2011.csv
# sal_lesi_o(1)_2012.csv
# sal_lesi_o(1)_2013.csv
# sal_lesi_o(1)_2014.csv
# singil_green_park(1)_2013.csv
# singil_green_park(1)_2014.csv
# ...

# %%
#Import data

Addr = './input/'

print('loading values_2011~2015')

angpyeongdong_noin_values_2011= pd.read_csv(Addr + 'angpyeongdong_noin_(1)_2011.csv', encoding = 'cp949')
angpyeongdong_noin_values_2012= pd.read_csv(Addr + 'angpyeongdong_noin_(1)_2012.csv', encoding = 'cp949')
angpyeongdong_noin_values_2013= pd.read_csv(Addr + 'angpyeongdong_noin_(1)_2013.csv', encoding = 'cp949')
angpyeongdong_noin_values_2014= pd.read_csv(Addr + 'angpyeongdong_noin_(1)_2014.csv', encoding = 'cp949')

daelimdong_yusuji_values_2013 = pd.read_csv(Addr + 'daelimdong_yusuji(3)_2013.csv',encoding = 'cp949')
daelimdong_yusuji_values_2014 = pd.read_csv(Addr + 'daelimdong_yusuji(3)_2014.csv', encoding = 'cp949')

dangsan_middle_school_values_2013 = pd.read_csv(Addr + 'dangsan_middle_school(2)_2013.csv',encoding = 'cp949')
dangsan_middle_school_values_2014 = pd.read_csv(Addr + 'dangsan_middle_school(2)_2014.csv',encoding = 'cp949')

duam_children_park_values_2013 = pd.read_csv(Addr + 'duam_children_park(1)_2013.csv',encoding = 'cp949')
duam_children_park_values_2014 = pd.read_csv(Addr + 'duam_children_park(1)_2014.csv',encoding = 'cp949')

kbs_values_2012 = pd.read_csv(Addr + 'kbs(2)_2012.csv',encoding = 'cp949')
kbs_values_2013 = pd.read_csv(Addr + 'kbs(2)_2013.csv',encoding = 'cp949')
kbs_values_2014 = pd.read_csv(Addr + 'kbs(2)_2014.csv',encoding = 'cp949')

kim_hospital_values_2013 = pd.read_csv(Addr + 'kim_hospital(1)_2013.csv',encoding = 'cp949')
kim_hospital_values_2014 = pd.read_csv(Addr + 'kim_hospital(1)_2014.csv',encoding = 'cp949')

munlaedong_bismul_peompeujang_values_2014 = pd.read_csv(Addr + 'munlaedong_bismul_peompeujang(3)_2014.csv',encoding = 'cp949')
munlaedong_bismul_peompeujang_values_2015 = pd.read_csv(Addr + 'munlaedong_bismul_peompeujang(3)_2015.csv',encoding = 'cp949')

munlae_green_park_values_2013 = pd.read_csv(Addr + 'munlae_green_park(1)_2013.csv',encoding = 'cp949')
munlae_green_park_values_2014 = pd.read_csv(Addr + 'munlae_green_park(1)_2014.csv',encoding = 'cp949')

national_assembly_hall_values_2012 = pd.read_csv(Addr + 'national_assembly_hall(2)_2012.csv',encoding = 'cp949')
national_assembly_hall_values_2014 = pd.read_csv(Addr + 'national_assembly_hall(2)_2014.csv',encoding = 'cp949')

sal_lesi_o_values_2011 = pd.read_csv(Addr + 'sal_lesi_o(1)_2011.csv',encoding = 'cp949')
sal_lesi_o_values_2012 = pd.read_csv(Addr + 'sal_lesi_o(1)_2012.csv',encoding = 'cp949')
sal_lesi_o_values_2013 = pd.read_csv(Addr + 'sal_lesi_o(1)_2013.csv',encoding = 'cp949')
sal_lesi_o_values_2014 = pd.read_csv(Addr + 'sal_lesi_o(1)_2014.csv',encoding = 'cp949')

singil_green_park_values_2013 = pd.read_csv(Addr + 'singil_green_park(1)_2013.csv',encoding = 'cp949')
singil_green_park_values_2014 = pd.read_csv(Addr + 'singil_green_park(1)_2014.csv',encoding = 'cp949')
singil_green_park_values_2015 = pd.read_csv(Addr + 'singil_green_park(1)_2015.csv',encoding = 'cp949')

yangpeong_rainwater_values_2011 = pd.read_csv(Addr + 'yangpeong_rainwater(3)_2011.csv',encoding = 'cp949')
yangpeong_rainwater_values_2012 = pd.read_csv(Addr + 'yangpeong_rainwater(3)_2012.csv',encoding = 'cp949')
yangpeong_rainwater_values_2013 = pd.read_csv(Addr + 'yangpeong_rainwater(3)_2013.csv',encoding = 'cp949')
yangpeong_rainwater_values_2014 = pd.read_csv(Addr + 'yangpeong_rainwater(3)_2014.csv',encoding = 'cp949')

yangpyeong_1_dong_yusuji_values_2012 = pd.read_csv(Addr + 'yangpyeong_1_dong_yusuji(3)_2012.csv',encoding = 'cp949')
yangpyeong_1_dong_yusuji_values_2013 = pd.read_csv(Addr + 'yangpyeong_1_dong_yusuji(3)_2013.csv',encoding = 'cp949')
yangpyeong_1_dong_yusuji_values_2014 = pd.read_csv(Addr + 'yangpyeong_1_dong_yusuji(3)_2014.csv',encoding = 'cp949')

yangpyeongdong_park_values_2012 = pd.read_csv(Addr + 'yangpyeongdong_park(3)_2012.csv',encoding = 'cp949')
yangpyeongdong_park_values_2013 = pd.read_csv(Addr + 'yangpyeongdong_park(3)_2013.csv',encoding = 'cp949')
yangpyeongdong_park_values_2014 = pd.read_csv(Addr + 'yangpyeongdong_park(3)_2014.csv',encoding = 'cp949')

yeongdeungpo_park_values_2011 = pd.read_csv(Addr + 'yeongdeungpo park(1)_2011.csv',encoding = 'cp949')
yeongdeungpo_park_values_2012 = pd.read_csv(Addr + 'yeongdeungpo park(1)_2012.csv',encoding = 'cp949')
yeongdeungpo_park_values_2013 = pd.read_csv(Addr + 'yeongdeungpo park(1)_2013.csv',encoding = 'cp949')
yeongdeungpo_park_values_2014 = pd.read_csv(Addr + 'yeongdeungpo park(1)_2014.csv',encoding = 'cp949')

yeouido_highschool_values_2014 = pd.read_csv(Addr + 'yeouido_highschool(1)_2014.csv',encoding = 'cp949')
yeouido_highschool_values_2015 = pd.read_csv(Addr + 'yeouido_highschool(1)_2015.csv',encoding = 'cp949')

yunjung_elementary_school_values_2014 = pd.read_csv(Addr + 'yunjung_elementary_school(1)_2014.csv',encoding = 'cp949')
yunjung_elementary_school_values_2015 = pd.read_csv(Addr + 'yunjung_elementary_school(1)_2015.csv',encoding = 'cp949')

dong_a_ecobil_apt_values_2011 = pd.read_csv(Addr + 'dong-a-ecobil_apt(1)_2011.csv',encoding = 'cp949')
dong_a_ecobil_apt_values_2012 = pd.read_csv(Addr + 'dong-a-ecobil_apt(1)_2012.csv',encoding = 'cp949')
dong_a_ecobil_apt_values_2013 = pd.read_csv(Addr + 'dong-a-ecobil_apt(1)_2013.csv',encoding = 'cp949')
dong_a_ecobil_apt_values_2014 = pd.read_csv(Addr + 'dong-a-ecobil_apt(1)_2014.csv',encoding = 'cp949')

sin_il_eolin_ijib_values_2011 = pd.read_csv(Addr + 'sin-il_eolin_ijib(1)_2011.csv',encoding = 'cp949')
sin_il_eolin_ijib_values_2012 = pd.read_csv(Addr + 'sin-il_eolin_ijib(1)_2012.csv',encoding = 'cp949')
sin_il_eolin_ijib_values_2013 = pd.read_csv(Addr + 'sin-il_eolin_ijib(1)_2013.csv',encoding = 'cp949')
sin_il_eolin_ijib_values_2014 = pd.read_csv(Addr + 'sin-il_eolin_ijib(1)_2014.csv',encoding = 'cp949')

""" a very long string ...... 
....that can span multiple lines
"""
print('loading info_2011~2015')
info = pd.read_csv(Addr + 'info.csv',encoding = 'cp949')
predict_data = pd.read_csv(Addr + 'predict_data.csv',encoding = 'cp949')
# Out:
# loading values_2011~2015
# loading info_2011~2015

# %%
angpyeongdong_noin_values_2011["일시"] = angpyeongdong_noin_values_2011["일시"].str.slice(start=0, stop=10)
angpyeongdong_noin_values_2012["일시"] = angpyeongdong_noin_values_2012["일시"].str.slice(start=0, stop=10)
angpyeongdong_noin_values_2013["일시"] = angpyeongdong_noin_values_2013["일시"].str.slice(start=0, stop=10)
angpyeongdong_noin_values_2014["일시"] = angpyeongdong_noin_values_2014["일시"].str.slice(start=0, stop=10)

daelimdong_yusuji_values_2013["일시"] = daelimdong_yusuji_values_2013["일시"].str.slice(start=0, stop=10)
daelimdong_yusuji_values_2014["일시"] = daelimdong_yusuji_values_2014["일시"].str.slice(start=0, stop=10)

dangsan_middle_school_values_2013["일시"] = dangsan_middle_school_values_2013["일시"].str.slice(start=0, stop=10)
dangsan_middle_school_values_2014["일시"] = dangsan_middle_school_values_2014["일시"].str.slice(start=0, stop=10)

duam_children_park_values_2013["일시"] = duam_children_park_values_2013["일시"].str.slice(start=0, stop=10)
duam_children_park_values_2014["일시"] = duam_children_park_values_2014["일시"].str.slice(start=0, stop=10)

kbs_values_2012["일시"] = kbs_values_2012["일시"].str.slice(start=0, stop=10)
kbs_values_2013["일시"] = kbs_values_2013["일시"].str.slice(start=0, stop=10)
kbs_values_2014["일시"] = kbs_values_2014["일시"].str.slice(start=0, stop=10)

kim_hospital_values_2013["일시"] = kim_hospital_values_2013["일시"].str.slice(start=0, stop=10)
kim_hospital_values_2014["일시"] = kim_hospital_values_2014["일시"].str.slice(start=0, stop=10)

munlaedong_bismul_peompeujang_values_2014["일시"] = munlaedong_bismul_peompeujang_values_2014["일시"].str.slice(start=0, stop=10)
munlaedong_bismul_peompeujang_values_2015["일시"] = munlaedong_bismul_peompeujang_values_2015["일시"].str.slice(start=0, stop=10)

munlae_green_park_values_2013["일시"] = munlae_green_park_values_2013["일시"].str.slice(start=0, stop=10)
munlae_green_park_values_2014["일시"] = munlae_green_park_values_2014["일시"].str.slice(start=0, stop=10)

national_assembly_hall_values_2012["일시"] = national_assembly_hall_values_2012["일시"].str.slice(start=0, stop=10)
national_assembly_hall_values_2014["일시"] = national_assembly_hall_values_2014["일시"].str.slice(start=0, stop=10)

sal_lesi_o_values_2011["일시"] = sal_lesi_o_values_2011["일시"].str.slice(start=0, stop=10)
sal_lesi_o_values_2012["일시"] = sal_lesi_o_values_2012["일시"].str.slice(start=0, stop=10)
sal_lesi_o_values_2013["일시"] = sal_lesi_o_values_2013["일시"].str.slice(start=0, stop=10)
sal_lesi_o_values_2014["일시"] = sal_lesi_o_values_2014["일시"].str.slice(start=0, stop=10)

singil_green_park_values_2013["일시"] = singil_green_park_values_2013["일시"].str.slice(start=0, stop=10)
singil_green_park_values_2014["일시"] = singil_green_park_values_2014["일시"].str.slice(start=0, stop=10)
singil_green_park_values_2015["일시"] = singil_green_park_values_2015["일시"].str.slice(start=0, stop=10)

yangpeong_rainwater_values_2011["일시"] = yangpeong_rainwater_values_2011["일시"].str.slice(start=0, stop=10)
yangpeong_rainwater_values_2012["일시"] = yangpeong_rainwater_values_2012["일시"].str.slice(start=0, stop=10)
yangpeong_rainwater_values_2013["일시"] = yangpeong_rainwater_values_2013["일시"].str.slice(start=0, stop=10)
yangpeong_rainwater_values_2014["일시"] = yangpeong_rainwater_values_2014["일시"].str.slice(start=0, stop=10)

yangpyeong_1_dong_yusuji_values_2012["일시"] = yangpyeong_1_dong_yusuji_values_2012["일시"].str.slice(start=0, stop=10)
yangpyeong_1_dong_yusuji_values_2013["일시"] = yangpyeong_1_dong_yusuji_values_2013["일시"].str.slice(start=0, stop=10)
yangpyeong_1_dong_yusuji_values_2014["일시"] = yangpyeong_1_dong_yusuji_values_2014["일시"].str.slice(start=0, stop=10)

yangpyeongdong_park_values_2012["일시"] = yangpyeongdong_park_values_2012["일시"].str.slice(start=0, stop=10)
yangpyeongdong_park_values_2013["일시"] = yangpyeongdong_park_values_2013["일시"].str.slice(start=0, stop=10)
yangpyeongdong_park_values_2014["일시"] = yangpyeongdong_park_values_2014["일시"].str.slice(start=0, stop=10)

yeongdeungpo_park_values_2011["일시"] = yeongdeungpo_park_values_2011["일시"].str.slice(start=0, stop=10)
yeongdeungpo_park_values_2012["일시"] = yeongdeungpo_park_values_2012["일시"].str.slice(start=0, stop=10)
yeongdeungpo_park_values_2013["일시"] = yeongdeungpo_park_values_2013["일시"].str.slice(start=0, stop=10)
yeongdeungpo_park_values_2014["일시"] = yeongdeungpo_park_values_2014["일시"].str.slice(start=0, stop=10)

yeouido_highschool_values_2014["일시"] = yeouido_highschool_values_2014["일시"].str.slice(start=0, stop=10)
yeouido_highschool_values_2015["일시"] = yeouido_highschool_values_2015["일시"].str.slice(start=0, stop=10)

yunjung_elementary_school_values_2014["일시"] = yunjung_elementary_school_values_2014["일시"].str.slice(start=0, stop=10)
yunjung_elementary_school_values_2015["일시"] = yunjung_elementary_school_values_2015["일시"].str.slice(start=0, stop=10)

dong_a_ecobil_apt_values_2011["일시"] = dong_a_ecobil_apt_values_2011["일시"].str.slice(start=0, stop=10)
dong_a_ecobil_apt_values_2012["일시"] = dong_a_ecobil_apt_values_2012["일시"].str.slice(start=0, stop=10)
dong_a_ecobil_apt_values_2013["일시"] = dong_a_ecobil_apt_values_2013["일시"].str.slice(start=0, stop=10)
dong_a_ecobil_apt_values_2014["일시"] = dong_a_ecobil_apt_values_2014["일시"].str.slice(start=0, stop=10)

sin_il_eolin_ijib_values_2011["일시"] = sin_il_eolin_ijib_values_2011["일시"].str.slice(start=0, stop=10)
sin_il_eolin_ijib_values_2012["일시"] = sin_il_eolin_ijib_values_2012["일시"].str.slice(start=0, stop=10)
sin_il_eolin_ijib_values_2013["일시"] = sin_il_eolin_ijib_values_2013["일시"].str.slice(start=0, stop=10)
sin_il_eolin_ijib_values_2014["일시"] = sin_il_eolin_ijib_values_2014["일시"].str.slice(start=0, stop=10)

# %%
sin_il_eolin_ijib_values_2013.head(3)
# Out:
#            일시  모기수
# 0  2013-06-19    0
# 1  2013-06-20    0
# 2  2013-06-21    0

# %%
date11 = DataFrame(columns=("일시","모기수"))
date12 = DataFrame(columns=("일시","모기수"))
date13 = DataFrame(columns=("일시","모기수"))
date14 = DataFrame(columns=("일시","모기수"))
date15 = DataFrame(columns=("일시","모기수"))

# %%
date11
# Out:
# Empty DataFrame
# Columns: [일시, 모기수]
# Index: []

# %%
date11["일시"] = pd.date_range("2011-05-01",'2011-12-31')
date12["일시"] = pd.date_range("2012-05-01",'2012-12-31')
date13["일시"] = pd.date_range("2013-05-01",'2013-12-31')
date14["일시"] = pd.date_range("2014-05-01",'2014-12-31')
date15["일시"] = pd.date_range("2015-05-01",'2015-12-31')

# %%
#type 이 다르기에 맞춰준다.

# %%
date11["일시"]= date11["일시"].astype(str)
date12["일시"]= date12["일시"].astype(str)
date13["일시"]= date13["일시"].astype(str)
date14["일시"]= date14["일시"].astype(str)
date15["일시"]= date15["일시"].astype(str)

# %%
#step1

# %%
angpyeongdong_noin_values_2011_set= pd.merge(date11,angpyeongdong_noin_values_2011, how="outer", on="일시")
angpyeongdong_noin_values_2011_set.drop('모기수_x', inplace=True, axis=1)
angpyeongdong_noin_values_2012_set= pd.merge(date12,angpyeongdong_noin_values_2012, how="outer", on="일시")
angpyeongdong_noin_values_2012_set.drop('모기수_x', inplace=True, axis=1)
angpyeongdong_noin_values_2013_set= pd.merge(date13,angpyeongdong_noin_values_2013, how="outer", on="일시")
angpyeongdong_noin_values_2013_set.drop('모기수_x', inplace=True, axis=1)
angpyeongdong_noin_values_2014_set= pd.merge(date14,angpyeongdong_noin_values_2014, how="outer", on="일시")
angpyeongdong_noin_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list1 = [angpyeongdong_noin_values_2011_set,angpyeongdong_noin_values_2012_set, angpyeongdong_noin_values_2013_set,
            angpyeongdong_noin_values_2014_set]

daelimdong_yusuji_values_2013_set= pd.merge(date13,daelimdong_yusuji_values_2013, how="outer", on="일시")
daelimdong_yusuji_values_2013_set.drop('모기수_x', inplace=True, axis=1)
daelimdong_yusuji_values_2014_set= pd.merge(date14,daelimdong_yusuji_values_2014, how="outer", on="일시")
daelimdong_yusuji_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list2 = [daelimdong_yusuji_values_2013_set, daelimdong_yusuji_values_2014_set]

dangsan_middle_school_values_2013_set= pd.merge(date13,dangsan_middle_school_values_2013, how="outer", on="일시")
dangsan_middle_school_values_2013_set.drop('모기수_x', inplace=True, axis=1)
dangsan_middle_school_values_2014_set= pd.merge(date14,dangsan_middle_school_values_2014, how="outer", on="일시")
dangsan_middle_school_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list3 = [dangsan_middle_school_values_2013_set, dangsan_middle_school_values_2014_set ]

duam_children_park_values_2013_set= pd.merge(date13,duam_children_park_values_2013, how="outer", on="일시")
duam_children_park_values_2013_set.drop('모기수_x', inplace=True, axis=1)
duam_children_park_values_2014_set= pd.merge(date14,duam_children_park_values_2014, how="outer", on="일시")
duam_children_park_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list4 = [duam_children_park_values_2013_set,duam_children_park_values_2014_set]

kbs_values_2012_set= pd.merge(date12,kbs_values_2012, how="outer", on="일시")
kbs_values_2012_set.drop('모기수_x', inplace=True, axis=1)
kbs_values_2013_set= pd.merge(date13,kbs_values_2013, how="outer", on="일시")
kbs_values_2013_set.drop('모기수_x', inplace=True, axis=1)
kbs_values_2014_set= pd.merge(date14,kbs_values_2014, how="outer", on="일시")
kbs_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list5 = [kbs_values_2012_set, kbs_values_2013_set, kbs_values_2014_set]

kim_hospital_values_2013_set= pd.merge(date13,kim_hospital_values_2013, how="outer", on="일시")
kim_hospital_values_2013_set.drop('모기수_x', inplace=True, axis=1)
kim_hospital_values_2014_set= pd.merge(date14,kim_hospital_values_2014, how="outer", on="일시")
kim_hospital_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list6 = [kim_hospital_values_2013_set, kim_hospital_values_2014_set]

munlaedong_bismul_peompeujang_values_2014_set= pd.merge(date14,munlaedong_bismul_peompeujang_values_2014, how="outer", on="일시")
munlaedong_bismul_peompeujang_values_2014_set.drop('모기수_x', inplace=True, axis=1)
munlaedong_bismul_peompeujang_values_2015_set= pd.merge(date15,munlaedong_bismul_peompeujang_values_2015, how="outer", on="일시")
munlaedong_bismul_peompeujang_values_2015_set.drop('모기수_x', inplace=True, axis=1)

tmp_list7 = [munlaedong_bismul_peompeujang_values_2014_set, munlaedong_bismul_peompeujang_values_2015_set]

munlae_green_park_values_2013_set= pd.merge(date13,munlae_green_park_values_2013, how="outer", on="일시")
munlae_green_park_values_2013_set.drop('모기수_x', inplace=True, axis=1)
munlae_green_park_values_2014_set= pd.merge(date14,munlae_green_park_values_2014, how="outer", on="일시")
munlae_green_park_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list8 = [munlae_green_park_values_2013_set, munlae_green_park_values_2014_set]

national_assembly_hall_values_2012_set= pd.merge(date12,national_assembly_hall_values_2012, how="outer", on="일시")
national_assembly_hall_values_2012_set.drop('모기수_x', inplace=True, axis=1)
national_assembly_hall_values_2014_set= pd.merge(date14,national_assembly_hall_values_2014, how="outer", on="일시")
national_assembly_hall_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list9 = [national_assembly_hall_values_2012_set, national_assembly_hall_values_2014_set]

sal_lesi_o_values_2011_set= pd.merge(date11,sal_lesi_o_values_2011, how="outer", on="일시")
sal_lesi_o_values_2011_set.drop('모기수_x', inplace=True, axis=1)
sal_lesi_o_values_2012_set= pd.merge(date12,sal_lesi_o_values_2012, how="outer", on="일시")
sal_lesi_o_values_2012_set.drop('모기수_x', inplace=True, axis=1)
sal_lesi_o_values_2013_set= pd.merge(date13,sal_lesi_o_values_2013, how="outer", on="일시")
sal_lesi_o_values_2013_set.drop('모기수_x', inplace=True, axis=1)
sal_lesi_o_values_2014_set= pd.merge(date14,sal_lesi_o_values_2014, how="outer", on="일시")
sal_lesi_o_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list10 = [sal_lesi_o_values_2011_set, sal_lesi_o_values_2012_set, sal_lesi_o_values_2013_set,
             sal_lesi_o_values_2014_set]

singil_green_park_values_2013_set= pd.merge(date13,singil_green_park_values_2013, how="outer", on="일시")
singil_green_park_values_2013_set.drop('모기수_x', inplace=True, axis=1)
singil_green_park_values_2014_set= pd.merge(date14,singil_green_park_values_2014, how="outer", on="일시")
singil_green_park_values_2014_set.drop('모기수_x', inplace=True, axis=1)
singil_green_park_values_2015_set= pd.merge(date15,singil_green_park_values_2015, how="outer", on="일시")
singil_green_park_values_2015_set.drop('모기수_x', inplace=True, axis=1)

tmp_list11 = [singil_green_park_values_2013_set, singil_green_park_values_2014_set, singil_green_park_values_2015_set]

yangpeong_rainwater_values_2011_set= pd.merge(date11,yangpeong_rainwater_values_2011, how="outer", on="일시")
yangpeong_rainwater_values_2011_set.drop('모기수_x', inplace=True, axis=1)
yangpeong_rainwater_values_2012_set= pd.merge(date12,yangpeong_rainwater_values_2012, how="outer", on="일시")
yangpeong_rainwater_values_2012_set.drop('모기수_x', inplace=True, axis=1)
yangpeong_rainwater_values_2013_set= pd.merge(date13,yangpeong_rainwater_values_2013, how="outer", on="일시")
yangpeong_rainwater_values_2013_set.drop('모기수_x', inplace=True, axis=1)
yangpeong_rainwater_values_2014_set= pd.merge(date14,yangpeong_rainwater_values_2014, how="outer", on="일시")
yangpeong_rainwater_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list12 = [yangpeong_rainwater_values_2011_set, yangpeong_rainwater_values_2012_set, 
             yangpeong_rainwater_values_2013_set, yangpeong_rainwater_values_2014_set]

yangpyeong_1_dong_yusuji_values_2012_set= pd.merge(date12,yangpyeong_1_dong_yusuji_values_2012, how="outer", on="일시")
yangpyeong_1_dong_yusuji_values_2012_set.drop('모기수_x', inplace=True, axis=1)
yangpyeong_1_dong_yusuji_values_2013_set= pd.merge(date13,yangpyeong_1_dong_yusuji_values_2013, how="outer", on="일시")
yangpyeong_1_dong_yusuji_values_2013_set.drop('모기수_x', inplace=True, axis=1)
yangpyeong_1_dong_yusuji_values_2014_set= pd.merge(date14,yangpyeong_1_dong_yusuji_values_2014, how="outer", on="일시")
yangpyeong_1_dong_yusuji_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list13 = [yangpyeong_1_dong_yusuji_values_2012_set, yangpyeong_1_dong_yusuji_values_2013_set,
             yangpyeong_1_dong_yusuji_values_2014_set]

yangpyeongdong_park_values_2012_set= pd.merge(date12,yangpyeongdong_park_values_2012, how="outer", on="일시")
yangpyeongdong_park_values_2012_set.drop('모기수_x', inplace=True, axis=1)
yangpyeongdong_park_values_2013_set= pd.merge(date13,yangpyeongdong_park_values_2013, how="outer", on="일시")
yangpyeongdong_park_values_2013_set.drop('모기수_x', inplace=True, axis=1)
yangpyeongdong_park_values_2014_set= pd.merge(date14,yangpyeongdong_park_values_2014, how="outer", on="일시")
yangpyeongdong_park_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list14 = [yangpyeongdong_park_values_2012_set, yangpyeongdong_park_values_2013_set, yangpyeongdong_park_values_2014_set]

yeongdeungpo_park_values_2011_set= pd.merge(date11,yeongdeungpo_park_values_2011, how="outer", on="일시")
yeongdeungpo_park_values_2011_set.drop('모기수_x', inplace=True, axis=1)
yeongdeungpo_park_values_2012_set= pd.merge(date12,yeongdeungpo_park_values_2012, how="outer", on="일시")
yeongdeungpo_park_values_2012_set.drop('모기수_x', inplace=True, axis=1)
yeongdeungpo_park_values_2013_set= pd.merge(date13,yeongdeungpo_park_values_2013, how="outer", on="일시")
yeongdeungpo_park_values_2013_set.drop('모기수_x', inplace=True, axis=1)
yeongdeungpo_park_values_2014_set= pd.merge(date14,yeongdeungpo_park_values_2014, how="outer", on="일시")
yeongdeungpo_park_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list15 = [yeongdeungpo_park_values_2011_set, yeongdeungpo_park_values_2012_set, yeongdeungpo_park_values_2013_set,
             yeongdeungpo_park_values_2014_set]

yeouido_highschool_values_2014_set= pd.merge(date14,yeouido_highschool_values_2014, how="outer", on="일시")
yeouido_highschool_values_2014_set.drop('모기수_x', inplace=True, axis=1)
yeouido_highschool_values_2015_set= pd.merge(date15,yeouido_highschool_values_2015, how="outer", on="일시")
yeouido_highschool_values_2015_set.drop('모기수_x', inplace=True, axis=1)

tmp_list16 = [yeouido_highschool_values_2014_set, yeouido_highschool_values_2015_set]

yunjung_elementary_school_values_2014_set= pd.merge(date14,yunjung_elementary_school_values_2014, how="outer", on="일시")
yunjung_elementary_school_values_2014_set.drop('모기수_x', inplace=True, axis=1)
yunjung_elementary_school_values_2015_set= pd.merge(date15,yunjung_elementary_school_values_2015, how="outer", on="일시")
yunjung_elementary_school_values_2015_set.drop('모기수_x', inplace=True, axis=1)

tmp_list17 = [yunjung_elementary_school_values_2014_set, yunjung_elementary_school_values_2015_set]

dong_a_ecobil_apt_values_2011_set= pd.merge(date11,dong_a_ecobil_apt_values_2011, how="outer", on="일시")
dong_a_ecobil_apt_values_2011_set.drop('모기수_x', inplace=True, axis=1)
dong_a_ecobil_apt_values_2012_set= pd.merge(date12,dong_a_ecobil_apt_values_2012, how="outer", on="일시")
dong_a_ecobil_apt_values_2012_set.drop('모기수_x', inplace=True, axis=1)
dong_a_ecobil_apt_values_2013_set= pd.merge(date13,dong_a_ecobil_apt_values_2013, how="outer", on="일시")
dong_a_ecobil_apt_values_2013_set.drop('모기수_x', inplace=True, axis=1)
dong_a_ecobil_apt_values_2014_set= pd.merge(date14,dong_a_ecobil_apt_values_2014, how="outer", on="일시")
dong_a_ecobil_apt_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list18 = [dong_a_ecobil_apt_values_2011_set, dong_a_ecobil_apt_values_2012_set, dong_a_ecobil_apt_values_2013_set,
             dong_a_ecobil_apt_values_2014_set]

sin_il_eolin_ijib_values_2011_set= pd.merge(date11,sin_il_eolin_ijib_values_2011, how="outer", on="일시")
sin_il_eolin_ijib_values_2011_set.drop('모기수_x', inplace=True, axis=1)
sin_il_eolin_ijib_values_2012_set= pd.merge(date12,sin_il_eolin_ijib_values_2012, how="outer", on="일시")
sin_il_eolin_ijib_values_2012_set.drop('모기수_x', inplace=True, axis=1)
sin_il_eolin_ijib_values_2013_set= pd.merge(date13,sin_il_eolin_ijib_values_2013, how="outer", on="일시")
sin_il_eolin_ijib_values_2013_set.drop('모기수_x', inplace=True, axis=1)
sin_il_eolin_ijib_values_2014_set= pd.merge(date14,sin_il_eolin_ijib_values_2014, how="outer", on="일시")
sin_il_eolin_ijib_values_2014_set.drop('모기수_x', inplace=True, axis=1)

tmp_list19 = [sin_il_eolin_ijib_values_2011_set, sin_il_eolin_ijib_values_2012_set, sin_il_eolin_ijib_values_2013_set,
             sin_il_eolin_ijib_values_2014_set]

# %%
angpyeongdong_noin_values = angpyeongdong_noin_values_2011_set.append([angpyeongdong_noin_values_2012_set, angpyeongdong_noin_values_2013_set,angpyeongdong_noin_values_2014_set])
daelimdong_yusuji_values = daelimdong_yusuji_values_2013_set.append([daelimdong_yusuji_values_2014_set])
dangsan_middle_school_values = dangsan_middle_school_values_2013_set.append([dangsan_middle_school_values_2014_set])
duam_children_park_values = duam_children_park_values_2013_set.append([duam_children_park_values_2014_set])
kbs_values = kbs_values_2012_set.append([kbs_values_2013_set, kbs_values_2014_set])
kim_hospital_values = kim_hospital_values_2013_set.append([kim_hospital_values_2014_set])
munlaedong_bismul_peompeujang_values = munlaedong_bismul_peompeujang_values_2014_set.append([munlaedong_bismul_peompeujang_values_2015_set])
munlae_green_park_values = munlae_green_park_values_2013_set.append([munlae_green_park_values_2014_set])
national_assembly_hall_values = national_assembly_hall_values_2012_set.append([national_assembly_hall_values_2014_set])
sal_lesi_o_values = sal_lesi_o_values_2011_set.append([sal_lesi_o_values_2012_set, sal_lesi_o_values_2013_set,sal_lesi_o_values_2014_set])
singil_green_park_values = singil_green_park_values_2013_set.append([singil_green_park_values_2014_set, singil_green_park_values_2015_set])
yangpeong_rainwater_values = yangpeong_rainwater_values_2011_set.append([yangpeong_rainwater_values_2012_set, yangpeong_rainwater_values_2013_set,yangpeong_rainwater_values_2014_set])
yangpyeong_1_dong_yusuji_values = yangpyeong_1_dong_yusuji_values_2012_set.append([yangpyeong_1_dong_yusuji_values_2013_set, yangpyeong_1_dong_yusuji_values_2014_set])
yangpyeongdong_park_values = yangpyeongdong_park_values_2012_set.append([yangpyeongdong_park_values_2013_set, yangpyeongdong_park_values_2014_set])
yeongdeungpo_park_values = yeongdeungpo_park_values_2011_set.append([yeongdeungpo_park_values_2012_set, yeongdeungpo_park_values_2013_set,yeongdeungpo_park_values_2014_set])
yeouido_highschool_values = yeouido_highschool_values_2014_set.append([yeouido_highschool_values_2015_set])
yunjung_elementary_school_values = yunjung_elementary_school_values_2014_set.append([yunjung_elementary_school_values_2015_set])
dong_a_ecobil_apt_values = dong_a_ecobil_apt_values_2011_set.append([dong_a_ecobil_apt_values_2012_set, dong_a_ecobil_apt_values_2013_set,dong_a_ecobil_apt_values_2014_set])
sin_il_eolin_ijib_values = sin_il_eolin_ijib_values_2011_set.append([sin_il_eolin_ijib_values_2012_set, sin_il_eolin_ijib_values_2013_set,sin_il_eolin_ijib_values_2014_set])

# %%
#step3의 평균값 넣기 전 결측값 처리 및 step2 (1000이상인 것들 1000으로)

# %%
li=[angpyeongdong_noin_values,daelimdong_yusuji_values,dangsan_middle_school_values,duam_children_park_values,
   kbs_values, kim_hospital_values, munlaedong_bismul_peompeujang_values, munlae_green_park_values,
   national_assembly_hall_values, sal_lesi_o_values, singil_green_park_values, yangpeong_rainwater_values,
   yangpyeong_1_dong_yusuji_values, yangpyeongdong_park_values, yeongdeungpo_park_values, yeouido_highschool_values,
   yunjung_elementary_school_values, dong_a_ecobil_apt_values, sin_il_eolin_ijib_values]

# %%
li[0] = li[0].reset_index(drop=True)

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize=(15,6))
li[0]['일시'] = pd.to_datetime(li[0]['일시'])
plt.plot(li[0]['일시'],li[0]['모기수_y'])
plt.show()

# %%
li=[angpyeongdong_noin_values,daelimdong_yusuji_values,dangsan_middle_school_values,duam_children_park_values,
   kbs_values, kim_hospital_values, munlaedong_bismul_peompeujang_values, munlae_green_park_values,
   national_assembly_hall_values, sal_lesi_o_values, singil_green_park_values, yangpeong_rainwater_values,
   yangpyeong_1_dong_yusuji_values, yangpyeongdong_park_values, yeongdeungpo_park_values, yeouido_highschool_values,
   yunjung_elementary_school_values, dong_a_ecobil_apt_values, sin_il_eolin_ijib_values]

for i in range(len(li)):
    li[i].ix[li[i]['모기수_y']>=10000,'모기수_y'] = None
    li[i].ix[li[i]['모기수_y']>1000,'모기수_y'] = 1000
    li[i] = li[i].reset_index(drop=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
#평균이 너무 다르다 .예제 
kbs_values_2012_set["일시"] = kbs_values_2012_set["일시"].str.slice(start=0, stop=7)
kbs_values_2013_set["일시"] = kbs_values_2013_set["일시"].str.slice(start=0, stop=7)
kbs_values_2014_set["일시"] = kbs_values_2014_set["일시"].str.slice(start=0, stop=7)

kbs_values_2012_set.groupby(kbs_values_2012_set.일시).mean()
# Out:
#              모기수_y
# 일시
# 2012-05   1.000000
# 2012-06   0.454545
# 2012-07   1.677419
# 2012-08  71.266667
# 2012-09   2.733333
# 2012-10   1.000000
# 2012-11        NaN
# 2012-12        NaN

# %%
kbs_values_2013_set.groupby(kbs_values_2013_set.일시).mean()
# Out:
#               모기수_y
# 일시
# 2013-05         NaN
# 2013-06   40.666667
# 2013-07  404.766667
# 2013-08   31.166667
# 2013-09   11.724138
# 2013-10   18.741935
# 2013-11   14.100000
# 2013-12    8.076923

# %%
kbs_values_2014_set.groupby(kbs_values_2014_set.일시).mean()
# Out:
#               모기수_y
# 일시
# 2014-05   31.258065
# 2014-06   69.862069
# 2014-07  100.322581
# 2014-08   38.806452
# 2014-09   48.966667
# 2014-10   11.967742
# 2014-11    7.500000
# 2014-12         NaN

# %%
# 전체 년도의 평균을 구한다 앞으로 결측값, 잡음 완화 후에 사용될 평균

# %%
kbs_tmp_values = kbs_values_2012_set.append([kbs_values_2013_set, kbs_values_2014_set])
kbs_tmp_values["일시"] = kbs_tmp_values["일시"].str.slice(start=5, stop=7)

kbs_tmp_values = kbs_tmp_values.groupby(kbs_tmp_values.일시).mean()

# %%
plt.figure(10, figsize=(15,6))
plt.plot(kbs_tmp_values['모기수_y'])
plt.show()

# %%
national_assembly_hall_values_tt = national_assembly_hall_values_2012_set.append([national_assembly_hall_values_2014_set ])
national_assembly_hall_values_tt["일시"] = national_assembly_hall_values_tt["일시"].str.slice(start=5, stop=7)
national_assembly_hall_values_tt = national_assembly_hall_values_tt.reset_index(drop=True)

# %%
national_assembly_hall_values_tt.groupby(national_assembly_hall_values_tt.일시).mean()
# Out:
#          모기수_y
# 일시
# 05   14.340426
# 06    7.898305
# 07   22.387097
# 08  296.193548
# 09    5.457627
# 10    1.108696
# 11    0.000000
# 12         NaN

# %%
#그림으로도 보여준다. 예제 kbs 
# step2,3 (결과 그래프화)

# %%
import itertools
tmp_list_set = [tmp_list1, tmp_list2,tmp_list3,tmp_list4,tmp_list5,tmp_list6,tmp_list7,tmp_list8,tmp_list9,tmp_list10,
               tmp_list11,tmp_list12,tmp_list13,tmp_list14,tmp_list15,tmp_list16,tmp_list17, tmp_list18,tmp_list19]

# %%
#step 1 평균값을 구하고 NAN값에 채워주기

# %%
i=0
arr = []
for i in range(len(tmp_list_set)):
    tmp_li = []
    for k in range(1,len(tmp_list_set[i])):
       tmp_li.append(tmp_list_set[i][k])
    tmp  = tmp_list_set[i][0].append(tmp_li)
    tmp["일시"] = tmp["일시"].str.slice(start=5, stop=7)
    
    tmp.ix[tmp['모기수_y']>=10000,'모기수_y'] = None
    tmp.ix[tmp['모기수_y']>1000,'모기수_y'] = 1000
    
    for k in range(len(tmp.groupby(tmp.일시).mean())):
        month_mean = np.round(tmp.groupby(tmp.일시).mean().values + 0.5)
        month_mean = list(itertools.chain.from_iterable(month_mean))
    
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='05'),'모기수_y'] = month_mean[0]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='06'),'모기수_y'] = month_mean[1]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='07'),'모기수_y'] = month_mean[2]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='08'),'모기수_y'] = month_mean[3]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='09'),'모기수_y'] = month_mean[4]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='10'),'모기수_y'] = month_mean[5]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='11'),'모기수_y'] = month_mean[6]
    tmp.ix[pd.isnull(tmp['모기수_y']) & (tmp["일시"]=='12'),'모기수_y'] = month_mean[7]
    
    tmp = tmp.reset_index(drop=True)
    li[i]['모기수_y'] = tmp['모기수_y']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.

# %%
#############################################

# %%
info.drop('지점', inplace=True, axis=1)

# %%
#step 4 일 강수량이 공백인 부분에 0으로 채워주기

# %%
info.loc[pd.isnull(info['일강수량(mm)']) ,'일강수량(mm)'] = 0

# %%
info.head(3)
# Out:
#            일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 상대습도(%)
# 0  2011-01-01      -6.8     -10.4      -2.9       0.0        61.0
# 1  2011-01-02      -5.4      -8.5      -1.2       0.0        62.3
# 2  2011-01-03      -4.5      -8.5      -0.3       0.0        66.4

# %%
loc = pd.DataFrame(columns=['Location'])
li[0] = pd.concat([loc[['Location']].reset_index(drop=True), li[0]], axis=1)
li[1] = pd.concat([loc[['Location']].reset_index(drop=True), li[1]], axis=1)
li[2] = pd.concat([loc[['Location']].reset_index(drop=True), li[2]], axis=1)
li[3] = pd.concat([loc[['Location']].reset_index(drop=True), li[3]], axis=1)
li[4] = pd.concat([loc[['Location']].reset_index(drop=True), li[4]], axis=1)
li[5] = pd.concat([loc[['Location']].reset_index(drop=True), li[5]], axis=1)
li[6] = pd.concat([loc[['Location']].reset_index(drop=True), li[6]], axis=1)
li[7] = pd.concat([loc[['Location']].reset_index(drop=True), li[7]], axis=1)
li[8] = pd.concat([loc[['Location']].reset_index(drop=True), li[8]], axis=1)
li[9] = pd.concat([loc[['Location']].reset_index(drop=True), li[9]], axis=1)
li[10] = pd.concat([loc[['Location']].reset_index(drop=True), li[10]], axis=1)
li[11] = pd.concat([loc[['Location']].reset_index(drop=True), li[11]], axis=1)
li[12] = pd.concat([loc[['Location']].reset_index(drop=True), li[12]], axis=1)
li[13] = pd.concat([loc[['Location']].reset_index(drop=True), li[13]], axis=1)
li[14] = pd.concat([loc[['Location']].reset_index(drop=True), li[14]], axis=1)
li[15] = pd.concat([loc[['Location']].reset_index(drop=True), li[15]], axis=1)
li[16] = pd.concat([loc[['Location']].reset_index(drop=True), li[16]], axis=1)
li[17] = pd.concat([loc[['Location']].reset_index(drop=True), li[17]], axis=1)
li[18] = pd.concat([loc[['Location']].reset_index(drop=True), li[18]], axis=1)

# %%
li[0]['Location']= 'yangpyeongdong_noin'
li[1]['Location']= 'daelimdong_yusuji'
li[2]['Location']= 'dangsan_middle_school'
li[3]['Location']= 'duam_children_park'
li[4]['Location']= 'kbs'
li[5]['Location']= 'kim_hospital'
li[6]['Location']= 'munlaedong_bismul_peompeujang'
li[7]['Location']= 'munlae_green_park'
li[8]['Location']= 'national_assembly_hall'
li[9]['Location']= 'sal_lesi_o'
li[10]['Location']= 'singil_green_park'
li[11]['Location']= 'yangpeong_rainwater'
li[12]['Location']= 'yangpyeong_1_dong_yusuji'
li[13]['Location']= 'yangpyeongdong_park'
li[14]['Location']= 'yeongdeungpo_park'
li[15]['Location']= 'yeouido_highschool'
li[16]['Location']= 'yunjung_elementary_school'
li[17]['Location']= 'dong_a_ecobil_apt'
li[18]['Location']= 'sin_il_eolin_ijib'

# %%
#step 6 상대습도의 누적값 구하기

# %%
info = info.reset_index(drop=True)
Hum = info["평균 상대습도(%)"]
Hum = Hum.to_frame(name=None)
Hum = pd.concat([info[['일시']].reset_index(drop=True), Hum], axis=1)
for i in range(1,61):
    Hum[i] = Hum['평균 상대습도(%)'].rolling(min_periods=i, window=i).sum()
    
Hum.loc[-1] = None
Hum.index = Hum.index + 1 
Hum = Hum.sort_index()

Hum_tmp = Hum
Hum_tmp = Hum_tmp.reset_index(drop=True)

Hum_tmp.drop('평균 상대습도(%)', inplace=True, axis=1)
Hum_tmp.drop('일시', inplace=True, axis=1)

Hum = pd.concat([info[['일시','평균 상대습도(%)']].reset_index(drop=True), Hum_tmp], axis=1)
Hum = Hum.drop(Hum.index[len(Hum)-1]) # 마지막 행 삭제
Hum_set= pd.merge(Hum,li[0], how="inner", on="일시")

# %%
location_set = []
for i in range(len(li)):
    tmp_loc = pd.concat([li[i][['Location']].reset_index(drop=True), Hum_set], axis=1)
    location_set.append(tmp_loc)
    location_set[i] =location_set[i].reset_index(drop=True)

# %%
# location 포함된 각 지역 누적 값 합치기

# %%
tmp = pd.DataFrame()
for i in range(19):
    tmp = pd.concat([tmp,location_set[i]], axis=0)
tmp =tmp.reset_index(drop=True)
multi_hum = tmp

# %%
# 전체 누적 값에 대한 상관계수 구하기 multi

# %%
hum_corr = multi_hum.corr(method='pearson', min_periods=1)
hum_corr.sort_values(['모기수_y'],axis =1)
# Out:
#                    1  평균 상대습도(%)        14         8        15        13  \
# 평균 상대습도(%)  0.653336    1.000000  0.473230  0.480147  0.473872  0.470363
# 1           1.000000    0.653336  0.557045  0.618727  0.554353  0.564722
# 2           0.907808    0.579118  0.640737  0.723557  0.634241  0.651433
# 3           0.809917    0.545946  0.709139  0.806581  0.700085  0.720154
# 4           0.746390    0.529056  0.762823  0.869977  0.753166  0.773737
# 5           0.704690    0.517569  0.805709  0.919465  0.795749  0.817064
# 6           0.673064    0.500618  0.841269  0.958469  0.830816  0.853905
# 7           0.642611    0.488302  0.872687  0.987359  0.861165  0.886853
# 8           0.618727    0.480147  0.901065  1.000000  0.888289  0.916380
# 9           0.601150    0.479196  0.926297  0.989275  0.912478  0.941581
# 10          0.590493    0.479777  0.948144  0.970249  0.934425  0.962674
# 11          0.582897    0.478598  0.966743  0.951136  0.953701  0.980276
# ...

# %%
hum_corr.to_csv("hum_data.csv")

# %%
#다른 변수도 적용

# %%
info = info.reset_index(drop=True)
Raf = info["일강수량(mm)"]
Raf = Raf.to_frame(name=None)
Raf = pd.concat([info[['일시']].reset_index(drop=True), Raf], axis=1)
for i in range(1,61):
    Raf[i] = Raf["일강수량(mm)"].rolling(min_periods=i, window=i).sum()
    
Raf.loc[-1] = None
Raf.index = Raf.index + 1 
Raf = Raf.sort_index()

Raf_tmp = Raf
Raf_tmp = Raf_tmp.reset_index(drop=True)

Raf_tmp.drop('일강수량(mm)', inplace=True, axis=1)
Raf_tmp.drop('일시', inplace=True, axis=1)

Raf = pd.concat([info[['일시','일강수량(mm)']].reset_index(drop=True), Raf_tmp], axis=1)
Raf = Raf.drop(Raf.index[len(Raf)-1]) # 마지막 행 삭제
Raf_set= pd.merge(Raf,li[0], how="inner", on="일시")

location_set = []
for i in range(len(li)):
    tmp_loc = pd.concat([li[i][['Location']].reset_index(drop=True), Raf_set], axis=1)
    location_set.append(tmp_loc)
    location_set[i] =location_set[i].reset_index(drop=True)
    
tmp = pd.DataFrame()
for i in range(19):
    tmp = pd.concat([tmp,location_set[i]], axis=0)
tmp =tmp.reset_index(drop=True)
multi_raf = tmp

raf_corr = multi_raf.corr(method='pearson', min_periods=1)
raf_corr.sort_values(['모기수_y'],axis =1)

# %%
info = info.reset_index(drop=True)
Tmx = info["최고기온(°C)"]
Tmx = Tmx.to_frame(name=None)
Tmx = pd.concat([info[['일시']].reset_index(drop=True), Tmx], axis=1)
for i in range(1,61):
    Tmx[i] = Tmx["최고기온(°C)"].rolling(min_periods=i, window=i).sum()
    
Tmx.loc[-1] = None
Tmx.index = Tmx.index + 1 
Tmx = Tmx.sort_index()

Tmx_tmp = Tmx
Tmx_tmp = Tmx_tmp.reset_index(drop=True)

Tmx_tmp.drop('최고기온(°C)', inplace=True, axis=1)
Tmx_tmp.drop('일시', inplace=True, axis=1)

Tmx = pd.concat([info[['일시','최고기온(°C)']].reset_index(drop=True), Tmx_tmp], axis=1)
Tmx = Tmx.drop(Tmx.index[len(Tmx)-1]) # 마지막 행 삭제
Tmx_set= pd.merge(Tmx,li[0], how="inner", on="일시")

location_set = []
for i in range(len(li)):
    tmp_loc = pd.concat([li[i][['Location']].reset_index(drop=True), Tmx_set], axis=1)
    location_set.append(tmp_loc)
    location_set[i] =location_set[i].reset_index(drop=True)
    
tmp = pd.DataFrame()
for i in range(19):
    tmp = pd.concat([tmp,location_set[i]], axis=0)
tmp =tmp.reset_index(drop=True)
multi_tmx = tmp

tmx_corr = multi_tmx.corr(method='pearson', min_periods=1)
tmx_corr.sort_values(['모기수_y'],axis =1)

# %%
tmx_corr.plot.scatter(x=1, y='모기수_y')
plt.show()

# %%
info = info.reset_index(drop=True)
Tmi = info["최저기온(°C)"]
Tmi = Tmi.to_frame(name=None)
Tmi = pd.concat([info[['일시']].reset_index(drop=True), Tmi], axis=1)
for i in range(1,61):
    Tmi[i] = Tmi["최저기온(°C)"].rolling(min_periods=i, window=i).sum()
    
Tmi.loc[-1] = None
Tmi.index = Tmi.index + 1 
Tmi = Tmi.sort_index()

Tmi_tmp = Tmi
Tmi_tmp = Tmi_tmp.reset_index(drop=True)

Tmi_tmp.drop('최저기온(°C)', inplace=True, axis=1)
Tmi_tmp.drop('일시', inplace=True, axis=1)

Tmi = pd.concat([info[['일시','최저기온(°C)']].reset_index(drop=True), Tmi_tmp], axis=1)
Tmi = Tmi.drop(Tmi.index[len(Tmi)-1]) # 마지막 행 삭제
Tmi_set= pd.merge(Tmi,li[0], how="inner", on="일시")

location_set = []
for i in range(len(li)):
    tmp_loc = pd.concat([li[i][['Location']].reset_index(drop=True), Tmi_set], axis=1)
    location_set.append(tmp_loc)
    location_set[i] =location_set[i].reset_index(drop=True)
    
tmp = pd.DataFrame()
for i in range(19):
    tmp = pd.concat([tmp,location_set[i]], axis=0)
tmp =tmp.reset_index(drop=True)
multi_tmi = tmp

tmi_corr = multi_tmi.corr(method='pearson', min_periods=1)
tmi_corr.sort_values(['모기수_y'],axis =1)

# %%
info = info.reset_index(drop=True)
Tav = info["평균기온(°C)"]
Tav = Tav.to_frame(name=None)
Tav = pd.concat([info[['일시']].reset_index(drop=True), Tav], axis=1)
for i in range(1,61):
    Tav[i] = Tav["평균기온(°C)"].rolling(min_periods=i, window=i).sum()
    
Tav.loc[-1] = None
Tav.index = Tav.index + 1 
Tav = Tav.sort_index()

Tav_tmp = Tav
Tav_tmp = Tav_tmp.reset_index(drop=True)

Tav_tmp.drop('평균기온(°C)', inplace=True, axis=1)
Tav_tmp.drop('일시', inplace=True, axis=1)

Tav = pd.concat([info[['일시','평균기온(°C)']].reset_index(drop=True), Tav_tmp], axis=1)
Tav = Tav.drop(Tav.index[len(Tav)-1]) # 마지막 행 삭제
Tav_set= pd.merge(Tav,li[0], how="inner", on="일시")

location_set = []
for i in range(len(li)):
    tmp_loc = pd.concat([li[i][['Location']].reset_index(drop=True), Tav_set], axis=1)
    location_set.append(tmp_loc)
    location_set[i] =location_set[i].reset_index(drop=True)
    
tmp = pd.DataFrame()
for i in range(19):
    tmp = pd.concat([tmp,location_set[i]], axis=0)
tmp =tmp.reset_index(drop=True)
multi_tav = tmp

tav_corr = multi_tav.corr(method='pearson', min_periods=1)
tav_corr.sort_values(['모기수_y'],axis =1)

# %%
# importance value 추출해 데이터 프레임에 저장 step8

# %%
imt_values = pd.DataFrame(columns = ['Hum', 'Raf', 'Tmx','Tmi','Tav'])
imt_values = [49, 32, 1, 1, 1]
imt_values_tmp_li =[]
for i in range(1,19):
    imt_values_tmp_li.append(li[i])

values = li[0].append(imt_values_tmp_li)
values =values.reset_index(drop=True)    
values.drop('모기수_y', inplace=True, axis=1)

values['Hum49'] = multi_hum[imt_values[0]]
values['Raf32'] = multi_raf[imt_values[1]]
values['Tmx1'] = multi_tmx[imt_values[2]].astype(int)
values['Tmi1'] = multi_tmi[imt_values[3]]
values['Tav1'] = multi_tav[imt_values[4]]

# %%
# 최종 변수로 지정된 df에 landuse 값 설정 step9

# %%
values['LandUse'] = 0

# %%
values.loc[values["Location"] =='yangpyeongdong_noin','LandUse'] = 1
values.loc[values["Location"] =='daelimdong_yusuji','LandUse'] = 3
values.loc[values["Location"] =='dangsan_middle_school','LandUse'] = 2
values.loc[values["Location"] =='dong_a-ecobil_apt','LandUse'] = 1
values.loc[values["Location"] =='duam_children_park','LandUse'] = 1
values.loc[values["Location"] =='kbs','LandUse'] = 2
values.loc[values["Location"] =='kim_hospital','LandUse'] = 1
values.loc[values["Location"] =='munlaedong_bismul_peompeujang','LandUse'] = 3
values.loc[values["Location"] =='munlae_green_park','LandUse'] = 1
values.loc[values["Location"] =='national_assembly_hall','LandUse'] = 2
values.loc[values["Location"] =='sal_lesi_o','LandUse'] = 1
values.loc[values["Location"] =='singil_green_park','LandUse'] = 1
values.loc[values["Location"] =='sin_il_eolin_ijib','LandUse'] = 1
values.loc[values["Location"] =='yangpeong_rainwater','LandUse'] = 3
values.loc[values["Location"] =='yangpyeong_1_dong_yusuji','LandUse'] = 3
values.loc[values["Location"] =='yangpyeongdong_park','LandUse'] = 1
values.loc[values["Location"] =='yeongdeungpo_park','LandUse'] = 1
values.loc[values["Location"] =='yeouido_highschool','LandUse'] = 1
values.loc[values["Location"] =='yunjung_elementary_school','LandUse'] = 1

# %%
# step 10 모기수와 level 지정

# %%
tmp_list2 = []
for i in range(19):
    tmp_list2.append(li[i]['모기수_y'])
    
Mosq = pd.concat(tmp_list2)
Mosq =Mosq.reset_index(drop=True)  
values['모기수'] = Mosq

# %%
values['level'] = 0

# %%
values.loc[ (values["모기수"] <= 20),'level'] = 1
values.loc[ (values["모기수"] > 20),'level'] = np.ceil(np.log2(values['모기수']/10))

#모기수 삭제 
#values.drop('모기수', inplace=True, axis=1)

# %%
values

# %%
values.drop('모기수', inplace=True, axis=1)

# %%
values.to_csv('data2.csv')

# %%
#Import data

Addr = './input/'

print('loading train, test data')
train_data = pd.read_csv(Addr + 'train_data.csv',encoding = 'cp949')
test_data = pd.read_csv(Addr + 'test_data.csv',encoding = 'cp949')

# %%
train_data
